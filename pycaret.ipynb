# %%
from pycaret.regression import *
from pycaret.classification import *
import pandas as pd
import numpy as np

# %%
df2 = pd.read_csv('abolone.csv')

# %%
s1= setup(df2, target='Rings', session_id = 1234,normalize = True,
           polynomial_features = True, trigonometry_features = True,
           feature_interaction=True, html=False)
# Out:
# Text(value="Following data types have been inferred automatically, if they are correct press enter to continue…
#                   Data Type
# Sex             Categorical
# Length              Numeric
# Diameter            Numeric
# Height              Numeric
# Whole weight        Numeric
# Shucked weight      Numeric
# Viscera weight      Numeric
# Shell weight        Numeric
# Rings                 Label
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# Setup Succesfully Completed!
#                                Description             Value
# 0                               session_id              1234
# 1                                   Target             Rings
# 2                              Target Type        Multiclass
# 3                            Label Encoded              None
# 4                            Original Data         (4177, 9)
# ...

# %%
s1
# Out:
#                   Model  Accuracy  AUC  Recall   Prec.      F1   Kappa  \
# lr  Logistic Regression    0.2751  0.0   0.165  0.2473  0.2494  0.1719
#
#        MCC  TT (Sec)
# lr  0.1745     2.363
#                       Model  Accuracy  AUC  Recall   Prec.      F1   Kappa  \
# lr      Logistic Regression    0.2751  0.0  0.1650  0.2473  0.2494  0.1719
# knn  K Neighbors Classifier    0.2333  0.0  0.1422  0.2064  0.2140  0.1309
#
#         MCC  TT (Sec)
# lr   0.1745     2.363
# knn  0.1317     0.031
#                       Model  Accuracy  AUC  Recall   Prec.      F1   Kappa  \
# lr      Logistic Regression    0.2751  0.0  0.1650  0.2473  0.2494  0.1719
# knn  K Neighbors Classifier    0.2333  0.0  0.1422  0.2064  0.2140  0.1309
# nb              Naive Bayes    0.0876  0.0  0.1200  0.1233  0.0868  0.0569
#
#         MCC  TT (Sec)
# lr   0.1745     2.363
# knn  0.1317     0.031
# nb   0.0680     0.021
#                         Model  Accuracy  AUC  Recall   Prec.      F1   Kappa  \
# ...

# %%
df = pd.read_csv('Elongation_tiny_regression.csv')

# %%
s = setup(df, target='Elong', session_id = 123,normalize = True,
           polynomial_features = True, trigonometry_features = True,
           feature_interaction=True, html=False)
# Out:
# Text(value="Following data types have been inferred automatically, if they are correct press enter to continue…
#       Data Type
# C       Numeric
# SI      Numeric
# MN      Numeric
# P       Numeric
# S       Numeric
# CU      Numeric
# MG      Numeric
# CR      Numeric
# NI      Numeric
# PB      Numeric
# AL      Numeric
# MO      Numeric
# TI      Numeric
# SN      Numeric
# V       Numeric
# ZN      Numeric
# CE      Numeric
# Elong     Label
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# Setup Succesfully Completed!
#                                Description             Value
# 0                               session_id               123
# 1                                   Target             Elong
# 2                            Original Data         (385, 18)
# 3                           Missing Values             False
# 4                         Numeric Features                17
# ...

# %%
compare_models()
# Out:
#                 Model     MAE      MSE    RMSE      R2   RMSLE    MAPE  \
# lr  Linear Regression  1.2092  17.1517  2.4046 -1.7566  0.1058  0.0908
#
#     TT (Sec)
# lr     0.861
#                    Model     MAE      MSE    RMSE      R2   RMSLE    MAPE  \
# lasso   Lasso Regression  1.3511   3.1338  1.7275 -0.0189  0.0975  0.0811
# lr     Linear Regression  1.2092  17.1517  2.4046 -1.7566  0.1058  0.0908
#
#        TT (Sec)
# lasso     0.014
# lr        0.861
#                    Model     MAE      MSE    RMSE      R2   RMSLE    MAPE  \
# ridge   Ridge Regression  0.9590   1.6637  1.2623  0.3957  0.0696  0.0561
# lasso   Lasso Regression  1.3511   3.1338  1.7275 -0.0189  0.0975  0.0811
# lr     Linear Regression  1.2092  17.1517  2.4046 -1.7566  0.1058  0.0908
#
#        TT (Sec)
# ridge     0.013
# lasso     0.014
# lr        0.861
#                    Model     MAE      MSE    RMSE      R2   RMSLE    MAPE  \
# ...

# %%
rf = create_model('rf')
# Out:
#          MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0     0.5302  0.4410  0.6641  0.7779  0.0364  0.0308
# 1     0.8481  0.9605  0.9801  0.4836  0.0532  0.0482
# 2     1.0793  1.7614  1.3272  0.4139  0.0744  0.0631
# 3     0.8505  1.4051  1.1854  0.6235  0.0698  0.0518
# 4     1.1221  4.3420  2.0837  0.4030  0.1609  0.0943
# 5     0.6589  0.6366  0.7978  0.6974  0.0444  0.0390
# 6     0.8161  1.0318  1.0158  0.5262  0.0542  0.0462
# 7     0.9896  1.6978  1.3030  0.5270  0.0693  0.0556
# 8     0.7790  1.2837  1.1330  0.5566  0.0568  0.0429
# 9     0.8183  0.8697  0.9326  0.5900  0.0505  0.0470
# Mean  0.8492  1.4430  1.1423  0.5599  0.0670  0.0519
# SD    0.1709  1.0480  0.3717  0.1120  0.0332  0.0164

# %%
plot_model(rf)

# %%
tuned_rf = tune_model(rf)
# Out:
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:   20.1s finished
#          MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0     0.5872  0.5117  0.7153  0.7423  0.0397  0.0344
# 1     0.7029  0.6531  0.8081  0.6489  0.0445  0.0403
# 2     0.9802  1.4320  1.1967  0.5235  0.0667  0.0574
# 3     0.9865  1.5743  1.2547  0.5782  0.0730  0.0596
# 4     1.1730  4.4874  2.1184  0.3830  0.1629  0.0981
# 5     0.6472  0.6558  0.8098  0.6882  0.0456  0.0388
# 6     0.8356  1.1447  1.0699  0.4744  0.0564  0.0469
# 7     0.9742  1.6520  1.2853  0.5398  0.0686  0.0543
# 8     0.7918  1.2906  1.1361  0.5542  0.0568  0.0437
# 9     0.7521  0.8308  0.9115  0.6083  0.0497  0.0434
# Mean  0.8431  1.4232  1.1306  0.5741  0.0664  0.0517
# SD    0.1731  1.0919  0.3808  0.0993  0.0339  0.0173

# %%
save_model(tuned_rf,'deployment_rf')
# Out:
# Transformation Pipeline and Model Succesfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[], ml_usecase='regression',
#                                        numerical_features=[], target='Elong',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_strategy='...
#                   RandomForestRegressor(bootstrap=True, ccp_alpha=0.0,
#                                         criterion='mse', max_depth=6,
#                                         max_features='log2', max_leaf_nodes=None,
# ...

# %%
deployment_rf = load_model('deployment_rf')
# Out:
# Transformation Pipeline and Model Successfully Loaded
